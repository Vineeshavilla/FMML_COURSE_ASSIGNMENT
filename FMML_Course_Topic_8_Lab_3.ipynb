# %% [markdown]
# <a href="https://colab.research.google.com/github/Vineeshavilla/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-07 16:58:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   183MB/s    in 0.4s
#
# 2022-06-07 16:58:47 (183 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23908   1303.2465v1  For the purposes of foreground estimation, the...    cs
# 13082  1507.05371v2  There is much empirical evidence that item-ite...    cs
# 28445  1706.06972v3  Convolutional sparse coding (CSC) improves spa...    cs
# 2474   1612.03364v1  Sparsity-constrained optimization is an import...    cs
# 1819   1704.06497v1  Bandit structured prediction describes a stoch...  stat
# ...             ...                                                ...   ...
# 40001  1709.02641v2  In this paper, we aim at the completion proble...    cs
# 9338    1302.4245v3  Gaussian processes are rich distributions over...  stat
# 12543  1802.08908v1  The rapid adoption of machine learning has inc...  stat
# 18889   1301.0611v1  This paper uses decision-theoretic principles ...    cs
# 35792   1208.2261v2  The growth of world-wide-web (WWW) spreads its...    cs
#
#                                                    title  year  \
# 23908  A Low-Complexity Algorithm for Static Backgrou...  2013
# 13082  Regret Guarantees for Item-Item Collaborative ...  2015
# 28445        Scalable Online Convolutional Sparse Coding  2017
# 2474   Technical Report: A Generalized Matching Pursu...  2016
# 1819   Bandit Structured Prediction for Neural Sequen...  2017
# ...                                                  ...   ...
# 40001  Completion of High Order Tensor Data with Miss...  2017
# 9338   Gaussian Process Kernels for Pattern Discovery...  2013
# 12543                Scalable Private Learning with PATE  2018
# 18889  Decision Principles to justify Carnap's Updati...  2012
# 35792  Analysis of Statistical Hypothesis based Learn...  2012
#
#                                                 keywords
# 23908  [foreground, estimation, background, unavailab...
# 13082  [empirical, collaborative, filtering, motivate...
# 28445  [convolutional, invariant, dictionary, algorit...
# 2474   [constrained, optimization, important, challen...
# 1819   [structured, prediction, describes, stochastic...
# ...                                                  ...
# 40001  [completion, factorization, completion, dimens...
# 9338   [processes, distributions, functions, nonparam...
# 12543  [increased, implications, sensitive, informati...
# 18889  [theoretic, principles, assessment, probabilit...
# 35792  [intangible, quantities, information, graduall...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23908    [foreground, estimation, background, unavailab...
# 13082    [empirical, collaborative, filtering, motivate...
# 28445    [convolutional, invariant, dictionary, algorit...
# 2474     [constrained, optimization, important, challen...
# 1819     [structured, prediction, describes, stochastic...
#                                ...
# 6861     [attention, exploitation, information, contain...
# 33153    [development, companies, throughout, companies...
# 18189    [interpret, electroencephalogram, recording, a...
# 6830     [memorization, connections, generalization, ad...
# 19813    [currently, arguments, explaining, evaluating,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8801 words.
# Out of those 4520 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="704eb278-187a-4962-a89a-feb6a6c3b989" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("704eb278-187a-4962-a89a-feb6a6c3b989")) {                    Plotly.newPlot(                        "704eb278-187a-4962-a89a-feb6a6c3b989",                        [{"x":["neighbourhood","estimated","requirements","frequency","labelling","cluttered","computational","experiments","segmentation","estimation","combination","unavailable","foreground","background","estimates","continuity","circumstances","complexity","enforcing","maintained","sequences","conditional","intervals","indirectly","practical","considerably","sequential","technique","structures","appropriate","filtering","candidate","qualitatively","framework","potentials","surveillance","conditions","intensity","algorithm","demonstrate","representative","fundamentally","guarantees","collaborative","understand","information","recommendations","empirical","recommendation","completion","algorithms","equivalently","performance","motivated","resulting","converges","direction","extensive","invariant","optimization","objective","alternating","stationary","reconstruction","convergence","efficient","subproblems","alleviate","convolutional","dictionary","convolution","solutions","theoretical","reformulation","multipliers","expensive","generalized","analogous","important","particular","statistic","constraints","specifically","knowledge","approximation","technical","constraint","challenging","demonstrates","statistics","structured","detection","nonlinear","applicability","connected","specialize","constrained","translation","describes","prediction","adaptation","predicted","incorporate","structure","generalization","performed","reduction","improvements","simulated","attention","furthermore","stochastic","recurrent","evaluation","magnitude","pedestrians","extensions","computation","indicative","detecting","discrimination","probability","applicants","analyzing","introduce","threshold","computationally","distributions","inference","decisions","discriminant","assertion","presented","probabilistic","illustrative","parameters","statistical","comparisons","providing","regression","efficiently","distribution","methodology","particularly","posterior","quantification","uncertainty","integration","addresses","classifiers","effective","predictions","challenges","processes","covariance","optimistic","efficiency","plausible","functions","reinforcement","simultaneous","literature","intractable","statistically","experience","principle","sacrifice","approaches","exploration","randomized","elucidate","forecasting","successfully","implications","available","frequently","interested","typically","functional","competing","applications","conjunction","multivariate","competitive","empirically","generally","equivalent","specialized","alternatively","encodings","established","problematic","representation","translated","techniques","consistency","theoretically","representations","experimental","satisfaction"],"y":[5,57,58,61,9,9,291,588,197,208,142,6,20,80,61,7,6,226,10,9,127,93,18,3,132,20,75,253,143,91,87,56,16,547,16,28,117,32,793,538,45,5,72,41,60,691,24,154,43,43,580,5,912,53,150,35,53,163,62,320,159,31,20,93,114,417,5,24,383,63,52,143,150,4,17,61,73,10,379,265,4,140,178,351,112,32,102,269,64,56,104,350,64,45,72,3,67,117,79,228,52,40,69,362,108,118,115,129,64,159,159,144,144,248,51,10,45,153,2,54,18,158,1,56,342,37,77,113,205,61,20,1,180,155,5,260,159,37,92,116,152,203,73,84,37,13,91,61,53,118,240,75,108,107,20,6,169,27,214,113,31,113,18,24,36,64,2,444,59,20,0,24,81,20,271,30,18,103,45,18,418,25,29,128,78,67,59,22,9,14,48,17,388,14,411,66,40,253,392,25],"type":"bar"},{"x":["neighbourhood","estimated","requirements","frequency","la ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4520,), (4520, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dualing</span> <span style=''>GANs</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>nets</span> <span style=''>(GANs)</span> <span style=''>are</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3037974683544304);'>promising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>from</span> <span style=''>samples</span> <span style=''>It</span> <span style=''>is</span> <span style=''>however</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>GAN</span> <span style=''>training</span> <span style=''>suffers</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instability</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>its</span> <span style=''>maximin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>ways</span> <span style=''>to</span> <span style=''>tackle</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instability</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>dualizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>We</span> <span style=''>start</span> <span style=''>from</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminators</span> <span style=''>in</span> <span style=''>which</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjugate</span> <span style=''>duality</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.41666666666666663);'>mechanism</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reformulate</span> <span style=''>the</span> <span style=''>saddle</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximization</span> <span style=''>problem</span> <span style=''>such</span> <span style=''>that</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generator</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>of</span> <span style=''>this</span> <span style=''>dualing</span> <span style=''>GAN</span> <span style=''>act</span> <span style=''>in</span> <span style=''>concert</span> <span style=''>We</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>how</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuition</span> <span style=''>to</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulations</span> <span style=''>For</span> <span style=''>GANs</span> <span style=''>with</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminators</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>remove</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>of</span> <span style=''>sampling</span> <span style=''>scores</span> <span style=''>for</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>from</span> <span style=''>noisy</span> <span style=''>samples</span> <span style=''>Existing</span> <span style=''>work</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>solution</span> <span style=''>by</span> <span style=''>using</span> <span style=''>leverage</span> <span style=''>based</span> <span style=''>scores</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>However</span> <span style=''>no</span> <span style=''>finite</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>and</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>optimal</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>To</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>which</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>mean</span> <span style=''>square</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>any</span> <span style=''>given</span> <span style=''>sampling</span> <span style=''>scores</span> <span style=''>Based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>Nonconvex</span> <span style=''>Sparse</span> <span style=''>Learning</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Progressive</span> <span style=''>Variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>stochastic</span> <span style=''>variance</span> <span style=''>reduced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>sparse</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>under</span> <span style=''>which</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>enjoys</span> <span style=''>strong</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.35410764872521244);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>and</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>accuracy</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.32758620689655166);'>dimensions</span> <span style=''>We</span> <span style=''>further</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asynchronous</span> <span style=''>parallel</span> <span style=''>variant</span> <span style=''>with</span> <span style=''>a</span> <span style=''>near</span> <span style=''>linear</span> <span style=''>speedup</span> <span style='background-color:rgba(255, 0, 0, 0.46179401993355473);'>Numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processing</span> <span style=''>of</span> <span style=''>Biosignal</span> <span style=''>Database</span> <span style=''>for</span> <span style=''>Emotion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recognition</span> <span style=''>with</span> <span style=''>Mahout</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigates</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>on</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>emotion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physiological</span> <span style=''>sensors</span> <span style=''>using</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>library</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>mode</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>run</span> <span style=''>a</span> <span style=''>random</span> <span style=''>forests</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>on</span> <span style=''>the</span> <span style=''>biosignal</span> <span style=''>data</span> <span style=''>which</span> <span style=''>have</span> <span style=''>been</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>to</span> <span style=''>form</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exclusive</span> <span style=''>groups</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>fashion</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Cloudera</span> <span style=''>cluster</span> <span style=''>using</span> <span style=''>Mahout</span> <span style=''>The</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>time</span> <span style=''>required</span> <span style=''>for</span> <span style=''>the</span> <span style=''>offline</span> <span style=''>training</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>of</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physiological</span> <span style=''>datasets</span> <span style=''>through</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08658318425760286)
# 	information (0.24722719141323793)
# 	segmentation (0.0704830053667263)
# 	experimental (0.1402504472271914)
# 	processing (0.11234347048300537)
# 	representation (0.13881932021466906)
# 	different (0.26475849731663686)
# 	detection (0.1252236135957066)
# 	recognition (0.13130590339892664)
# 	convolutional (0.1370304114490161)
#
# Some Statistics words are:
# 	variables (0.13665835411471322)
# 	stochastic (0.14364089775561098)
# 	statistical (0.15211970074812967)
# 	theoretical (0.15012468827930175)
# 	estimation (0.17356608478802993)
# 	distribution (0.18154613466334166)
# 	dimensional (0.18453865336658354)
# 	algorithm (0.40448877805486283)
# 	inference (0.19600997506234413)
# 	regression (0.18802992518703243)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b306ddaa-6668-4eb5-8add-74d70878bea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b306ddaa-6668-4eb5-8add-74d70878bea6")) {
#                     Plotly.newPlot(
#                         'b306ddaa-6668-4eb5-8add-74d70878bea6',
#                         [{"type": "bar", "x": ["difference", "platforms", "analyzing", "different", "behaviors", "interests", "paragraphs", "understanding", "engagement", "collecting", "nonetheless", "displayed", "wikipedia", "generated", "significant", "proficiency", "languages", "primarily", "multilingual", "computational", "formidable", "complexity", "factorizes", "supervised", "multivariate", "experimental", "corrected", "illustrate", "framework", "therefore", "parametric", "introduce", "techniques", "bivariate", "factorization", "adaptation", "presented", "functions", "distributions", "regression", "technique", "polynomial", "candidates", "transformations", "parameters", "affinities", "validated", "selection", "outperforming", "correspondences", "correspondence", "estimation", "synthetic", "remaining", "especially", "conditions", "calibrated", "eliminating", "observing", "algorithm", "available", "knowledge", "fundamental", "intrinsic", "implementation", "constraints", "efficiently", "statistics", "classification", "principal", "experiments", "relationships", "ubiquitous", "construct", "classical", "computationally", "performance", "prohibitive", "randomness", "clustering", "algorithms", "canonical", "randomized", "achieving", "demonstrate", "component", "nonlinear", "correlation", "requirements", "traditional", "variables", "variational", "maximization", "selecting", "particular", "interpretation", "likelihood", "components", "procedure", "separately", "difficult", "unsupervised", "themselves", "relaxation", "expectation", "illustrated", "unlabeled", "maximized", "microarray", "dimensional", "practitioner", "probabilistic", "interpreted", "computation", "drawbacks", "optimizer", "performances", "suggestion", "correlated", "optimization", "information", "approximation", "significantly", "continuous", "dimension", "derivative", "discretized", "introduces", "evaluations", "numerical", "generalized", "sequential", "applications", "restricted", "discretization", "benchmarks", "cumulative", "sequentially", "deterministic", "probability", "independent", "informativeness", "suboptimal", "dependent", "parameter", "simulated", "scalability", "operations", "interaction", "inference", "processes", "nonparametric", "efficiency", "furthermore", "representative", "improvement", "triggering", "formulate", "competitive", "classifiers", "detecting", "convolutional", "cascading", "retraining", "recognizing", "exploiting", "relatively", "classified", "researchers", "determining", "approximating", "extremely", "generating", "feedforward", "appropriate", "generalization", "literature", "fragments", "increasing", "important", "universal", "practical", "sufficiently", "generates", "intervals", "activation", "promising", "convergence", "configuration", "cognitive", "connectome", "extracted", "groupings", "variations", "architecture", "hierarchical", "connectivity", "visualize", "resolution", "decompositions", "variability", "decompose", "precisions", "representations", "adjacency", "represents", "resolutions", "corresponds", "precision", "suggested", "representation", "autoencoder", "structures", "existence", "faithfully", "effectiveness", "underlying", "represent", "representing", "expressions", "unfortunately", "influence", "reinforcement", "sequences", "corresponding", "molecular", "discriminates", "successfully", "improving", "structure", "generative", "beginning", "individual", "evaluating", "mathematical", "recurrent", "instances", "approaches", "generally", "capacitated", "identifies", "established", "variation", "challenging", "automated", "efficient", "imitation", "experiences", "previously", "evolutionary", "encountered", "intelligent", "comprehensive", "particularly", "replicate", "structured", "optimized", "transfers", "operators", "methodologies", "innovations", "assimilate", "effective", "incorporates", "hyperparameters", "interpretable", "alternative", "automatically", "estimating", "conceptually", "interpretability", "situation", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bivariate
# 	precisions
# 	phenotypes
# 	worsening
# 	ascending
# 	jackknife
# 	reversing
# 	invertible
# 	stagewise
# 	varepsilon
# 	hermitian
# 	heckerman
# 	dobrushins
# 	exponents
# 	mcallester
# 	kontorovich
# 	bernstein
# 	resolvable
# 	microbial
# 	unnormalized
# Some words which never appear in Statistics papers:
# 	paragraphs
# 	cascading
# 	capacitated
# 	transfers
# 	syntactic
# 	antecedents
# 	coreference
# 	deblurring
# 	historically
# 	commonsense
# 	interpersonal
# 	analogical
# 	monocular
# 	transducer
# 	compilation
# 	propositional
# 	implicates
# 	connectives
# 	conscious
# 	axiomatization

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082994203970897e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
